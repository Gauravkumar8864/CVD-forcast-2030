# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('CVD_Analysis').getOrCreate()

# %%
df = spark.read.csv('dataset/CVD.csv', header=True, inferSchema=True)

# %%
df.show()

# %%
df.printSchema()

# %%
df.describe().show()

# %%
from pyspark.ml.feature import VectorAssembler

# %%
feature_cols = ['Year']

# %%
assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")

# %%
final_df = assembler.transform(df)

# %%
from pyspark.ml.regression import LinearRegression

# %%
train_data, test_data = final_df.randomSplit([0.8, 0.2])

# %%
lr = LinearRegression(featuresCol='features', labelCol='Death Rate')

# %%
model = lr.fit(train_data)

# %%
test_results = model.evaluate(test_data)

# %%
test_results.residuals.show()

# %%
print(f'RMSE: {test_results.rootMeanSquaredError}')

# %%
future_df = spark.createDataFrame([(2023,)], ['Year'])

# %%
future_df = assembler.transform(future_df)

# %%
prediction = model.transform(future_df)

# %%
prediction.show()

# %% [markdown]
# ## Summary of Findings
#
# The linear regression model was trained on the CVD death rate data from 2010 to 2020. The model was then used to predict the death rate for 2023.
#
# The model predicts a death rate of [predicted value] for 2023. The RMSE of the model on the test data is [RMSE value]. This indicates that the model's predictions are, on average, [RMSE value] units away from the actual values.
#
# Further analysis could involve using more features, trying different models, and performing more in-depth feature engineering to improve the model's accuracy.
