# %% [markdown]
# # CVD Death Rate Dataset — Exploratory Data Analysis (EDA)
#
# This notebook provides a clean exploratory analysis for the U.S. **Cardiovascular Disease (CVD)** death rate dataset.
#
# ### ⚠️ Important Note
# This notebook is for **EDA only**.
#
# 👉 The **forecasting pipeline (2021–2030)** is implemented in:
# **`src/advanced_pipeline.py`**
#
# Here we only explore trends and patterns in the dataset (2010–2020).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Load Dataset

# %%
# adjust the path if needed
df = pd.read_csv('../dataset/CVD.csv')
df.head()

# %% [markdown]
# ## 2. Basic Dataset Info

# %%
df.info()

# %%
df.describe(include='all')

# %% [markdown]
# ## 3. Clean Necessary Columns

# %%
data = df.copy()

data['Year'] = pd.to_numeric(data['Year'], errors='coerce')
data['Data_Value'] = pd.to_numeric(data['Data_Value'], errors='coerce')

data = data[(data['Year'] >= 2010) & (data['Year'] <= 2020)]
data = data.dropna(subset=['Data_Value'])

data.head()

# %% [markdown]
# ## 4. Missing Value Heatmap

# %%
plt.figure(figsize=(12, 5))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Value Matrix')
plt.show()

# %% [markdown]
# ## 5. Distribution of CVD Death Rate

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['Data_Value'], bins=40, kde=True)
plt.xlabel('CVD Death Rate')
plt.title('Distribution of CVD Death Rates (2010–2020)')
plt.show()

# %% [markdown]
# ## 6. National Trend (2010–2020)

# %%
yearly = data.groupby('Year')['Data_Value'].mean().reset_index()

plt.figure(figsize=(10, 5))
plt.plot(yearly['Year'], yearly['Data_Value'], marker='o')
plt.xlabel('Year')
plt.ylabel('Mean Death Rate')
plt.title('National Mean CVD Death Rate Trend (2010–2020)')
plt.grid(True)
plt.show()

yearly

# %% [markdown]
# ## 7. State-Level Average (Top 10 States)

# %%
state_avg = data.groupby('LocationAbbr')['Data_Value'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=state_avg.index, y=state_avg.values)
plt.title('Top 10 States by Highest Average CVD Death Rate')
plt.ylabel('Avg Death Rate')
plt.xlabel('State')
plt.show()

state_avg

# %% [markdown]
# ## 8. Correlation Analysis

# %%
numeric_cols = ['Data_Value', 'Year']

plt.figure(figsize=(5, 4))
sns.heatmap(data[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## 9. Geographic Spread (Longitude / Latitude)

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(
    data=data.sample(5000),
    x='X_long',
    y='Y_lat',
    hue='Data_Value',
    palette='viridis',
    legend=False
)
plt.title('Geographic Distribution of CVD Death Rates')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## 10. Stratification Analysis (Age, Gender, etc.)

# %%
strat = data.groupby('Stratification1')['Data_Value'].mean().sort_values(ascending=False)

plt.figure(figsize=(12, 5))
sns.barplot(x=strat.index, y=strat.values)
plt.xticks(rotation=45)
plt.title('Mean CVD Death Rate by Stratification Type')
plt.ylabel('Mean Death Rate')
plt.show()

strat

# %% [markdown]
# # Summary of Insights
#
# ### ✔ National CVD death rates (2010–2020) are mostly stable.
# ### ✔ Some states consistently have much higher death rates.
# ### ✔ Stratification groups (age, sex, race) show strong differences.
# ### ✔ No major missing data problems.
# ### ✔ Dataset has moderate variance, suitable for forecasting.
#
# ---
#
# ### ⚠️ Forecasting Note
# All **forecasting (2021–2030)** is implemented in:
# `src/advanced_pipeline.py`
#
# This notebook is only for:
# - exploratory data analysis
# - understanding the dataset
# - visualizing patterns
# - building intuition before modeling
